# %%
import sqlalchemy as sql
import pandas as pd
import numpy as np

# %%
dfbio_1 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_biometric_0_500000.csv')
dfbio_2 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_biometric_500000_1000000.csv')
dfbio_3 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_biometric_1000000_1500000.csv')
dfbio_4 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_biometric_1500000_1861108.csv')

# %%
#dfbio_1.tail(20)
#dfbio_2.head(21)
#dfbio_3.tail()
dfbio_4.tail(20)
# Out:
#               date        state                    district  pincode  \
# 361088  29-12-2025  West Bengal           South 24 Parganas   743375
# 361089  29-12-2025  West Bengal           South 24 Parganas   743378
# 361090  29-12-2025  West Bengal           South 24 Parganas   743384
# 361091  29-12-2025  West Bengal           South 24 Parganas   743392
# 361092  29-12-2025  West Bengal           South 24 Parganas   743502
# 361093  29-12-2025  West Bengal              South Dinajpur   733126
# 361094  29-12-2025  West Bengal              South Dinajpur   733140
# 361095  29-12-2025  West Bengal              South Dinajpur   733145
# 361096  29-12-2025  West Bengal              South Dinajpur   733153
# 361097  29-12-2025  West Bengal              South Dinajpur   733155
# 361098  29-12-2025  West Bengal  South Twenty Four Parganas   700084
# 361099  29-12-2025  West Bengal  South Twenty Four Parganas   700145
# 361100  29-12-2025  West Bengal  South Twenty Four Parganas   743348
# ...

# %%
dfbio_1.describe()
dfbio_2.describe()
dfbio_3.describe()
dfbio_4.describe()
# Out:
#              pincode   bio_age_5_17    bio_age_17_
# count  361108.000000  361108.000000  361108.000000
# mean   522148.027720       8.203139       7.377469
# std    196163.123982      16.473975      12.690448
# min    110001.000000       0.000000       0.000000
# 25%    393030.000000       1.000000       1.000000
# 50%    522657.000000       3.000000       3.000000
# 75%    683548.250000       9.000000       8.000000
# max    855456.000000     723.000000     383.000000

# %%
#dfbio_3.shape
dfbio_4.shape
# Out:
# (361108, 6)

# %%
dfbio_1.isnull().sum()
#dfbio_2.isnull().sum()
#dfbio_3.isnull().sum()
#dfbio_4.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %% [markdown]
# WHOLE COMBINED BIOMETRIC DATA

# %%
Combined_bio  =pd.concat([dfbio_1, dfbio_2, dfbio_3, dfbio_4], ignore_index=True)

# %%
Combined_bio
# Out:
#                date              state        district  pincode  bio_age_5_17  \
# 0        01-03-2025            Haryana    Mahendragarh   123029           280
# 1        01-03-2025              Bihar       Madhepura   852121           144
# 2        01-03-2025  Jammu and Kashmir           Punch   185101           643
# 3        01-03-2025              Bihar         Bhojpur   802158           256
# 4        01-03-2025         Tamil Nadu         Madurai   625514           271
# ...             ...                ...             ...      ...           ...
# 1861103  29-12-2025        West Bengal  Uttar Dinajpur   733201             4
# 1861104  29-12-2025        West Bengal  Uttar Dinajpur   733213             0
# 1861105  29-12-2025        West Bengal  West Midnapore   721304             0
# 1861106  29-12-2025        West Bengal  West Midnapore   721451             2
# 1861107  29-12-2025        West Bengal  West Midnapore   721457             0
#
#          bio_age_17_
# ...

# %%
Combined_bio.shape
# Out:
# (1861108, 6)

# %%
demo_1 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_demographic_0_500000.csv')
demo_2 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_demographic_500000_1000000.csv')
demo_3 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_demographic_1000000_1500000.csv')
demo_4 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_demographic_1500000_2000000.csv')
demo_5 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_demographic_2000000_2071700.csv')

# %%
#demo_2.tail()
#demo_3.tail()
#demo_4.tail()
demo_5.tail(30)
#demo_1.shape
# Out:
#              date        state                    district  pincode  \
# 71670  29-12-2025  West Bengal           South 24 Parganas   743383
# 71671  29-12-2025  West Bengal           South 24 Parganas   743385
# 71672  29-12-2025  West Bengal           South 24 Parganas   743387
# 71673  29-12-2025  West Bengal           South 24 Parganas   743503
# 71674  29-12-2025  West Bengal           South 24 Parganas   743513
# 71675  29-12-2025  West Bengal           South 24 Parganas   743609
# 71676  29-12-2025  West Bengal           South 24 Parganas   743611
# 71677  29-12-2025  West Bengal              South Dinajpur   733133
# 71678  29-12-2025  West Bengal  South Twenty Four Parganas   700008
# 71679  29-12-2025  West Bengal  South Twenty Four Parganas   700063
# 71680  29-12-2025  West Bengal  South Twenty Four Parganas   700070
# 71681  29-12-2025  West Bengal  South Twenty Four Parganas   700140
# 71682  29-12-2025  West Bengal  South Twenty Four Parganas   743318
# ...

# %%
demo_5.shape
# Out:
# (71700, 6)

# %%
demo_3.isnull().sum()
# Out:
# date             0
# state            0
# district         0
# pincode          0
# demo_age_5_17    0
# demo_age_17_     0
# dtype: int64

# %%
demo_3.describe()
# Out:
#              pincode  demo_age_5_17   demo_age_17_
# count  500000.000000  500000.000000  500000.000000
# mean   529598.351996       2.148640      19.830852
# std    196389.490902      13.852425     113.525472
# min    110001.000000       0.000000       0.000000
# 25%    400053.000000       0.000000       2.000000
# 50%    530013.000000       1.000000       6.000000
# 75%    695310.250000       2.000000      15.000000
# max    855456.000000    2690.000000   14314.000000

# %% [markdown]
# WHOLE COMBINED DEMOGRAPHIC DATA

# %%
combined_demo = pd.concat([demo_1, demo_2, demo_3, demo_4, demo_5], ignore_index=True)

# %%
combined_demo
# Out:
#                date           state        district  pincode  demo_age_5_17  \
# 0        01-03-2025   Uttar Pradesh       Gorakhpur   273213             49
# 1        01-03-2025  Andhra Pradesh        Chittoor   517132             22
# 2        01-03-2025         Gujarat          Rajkot   360006             65
# 3        01-03-2025  Andhra Pradesh      Srikakulam   532484             24
# 4        01-03-2025       Rajasthan         Udaipur   313801             45
# ...             ...             ...             ...      ...            ...
# 2071695  29-12-2025     West Bengal  West Midnapore   721212              0
# 2071696  29-12-2025     West Bengal  West Midnapore   721420              0
# 2071697  29-12-2025     West Bengal  West Midnapore   721424              0
# 2071698  29-12-2025     West Bengal  West Midnapore   721426              0
# 2071699  29-12-2025     West Bengal         hooghly   712701              0
#
#          demo_age_17_
# 0                 529
# ...

# %%
enro_1 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_enrolment_0_500000.csv')
enro_2 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_enrolment_500000_1000000.csv')
enro_3 = pd.read_csv(r'D:\ADH HACKATHON\HProject\api_data_aadhar_enrolment_1000000_1006029.csv')

# %%
#enro_1.tail()
#enro_2.tail()
enro_3.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
enro_1.shape
# Out:
# (500000, 7)

# %%
enro_3.describe()
# Out:
#              pincode      age_0_5     age_5_17  age_18_greater
# count    6029.000000  6029.000000  6029.000000     6029.000000
# mean   518765.547023     3.606734     3.493448        0.096533
# std    193308.752319     6.055847     6.694502        0.479475
# min    110003.000000     0.000000     0.000000        0.000000
# 25%    380022.000000     1.000000     0.000000        0.000000
# 50%    518005.000000     2.000000     1.000000        0.000000
# 75%    685595.000000     4.000000     3.000000        0.000000
# max    855116.000000   102.000000    89.000000        9.000000

# %% [markdown]
# WHOLE COMBINED ENROLLMENT DATA

# %%
combined_enro = pd.concat([enro_1, enro_2, enro_3], ignore_index=True)

# %%
combined_enro.shape
# Out:
# (1006029, 7)

# %%
#combined_enro.head(2000)
combined_demo.head(2000)
#Combined_bio.head(100)
# Out:
#             date           state           district  pincode  demo_age_5_17  \
# 0     01-03-2025   Uttar Pradesh          Gorakhpur   273213             49
# 1     01-03-2025  Andhra Pradesh           Chittoor   517132             22
# 2     01-03-2025         Gujarat             Rajkot   360006             65
# 3     01-03-2025  Andhra Pradesh         Srikakulam   532484             24
# 4     01-03-2025       Rajasthan            Udaipur   313801             45
# ...          ...             ...                ...      ...            ...
# 1995  01-03-2025     Maharashtra               Pune   411033            189
# 1996  01-03-2025   Uttar Pradesh             Ballia   277123             49
# 1997  01-03-2025       Rajasthan          Rajsamand   313329             55
# 1998  01-03-2025           Bihar               Gaya   824118            162
# 1999  01-03-2025          Punjab  Sri Muktsar Sahib   151210             21
#
#       demo_age_17_
# 0              529
# ...

# %%
# !pip install mysqlclient

# %%
from sqlalchemy import create_engine

# MySQL connection
username = "root"
password = "root"
host = "localhost"
port = "3306"
database = "uidai"

engine = create_engine(f"mysql+mysqldb://{username}:{password}@{host}:{port}/{database}")

# Writes DataFrame to MySQL
table_name = "enrollment"  # choose any table name
combined_enro.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 1006125

# %%
from sqlalchemy import create_engine

# MySQL connection
username = "root"
password = "root"
host = "localhost"
port = "3306"
database = "uidai"

engine = create_engine(f"mysql+mysqldb://{username}:{password}@{host}:{port}/{database}")

# Writes DataFrame to MySQL
table_name = "demographic"  # choose any table name
combined_demo.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 2072222

# %%
from sqlalchemy import create_engine

# MySQL connection
username = "root"
password = "root"
host = "localhost"
port = "3306"
database = "uidai"

engine = create_engine(f"mysql+mysqldb://{username}:{password}@{host}:{port}/{database}")

# Writes DataFrame to MySQL
table_name = "biometric"  # choose any table name
Combined_bio.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 1861332

# %%
#state column has '100000' value which was irrelevant
indexes_to_drop = combined_demo[combined_demo['state'] == '100000'].index

# 2. Drop them
combined_demo.drop(indexes_to_drop, inplace=True)

# %%
pd.read_sql("select count(state) , state  from demographic group by state;",engine)
# Out:
#     count(state)                      state
# 0         167889              Uttar Pradesh
# 1         207742             Andhra Pradesh
# 2          96399                    Gujarat
# 3          89510                  Rajasthan
# 4         153958                  Karnataka
# 5         169070                West Bangal
# 6          89088                  Telangana
# 7         105935                     Odisha
# 8         162243                Maharashtra
# 9         105515                     Kerala
# 10         97623                      Bihar
# 11        196858                 Tamil Nadu
# 12         76364             Madhya Pradesh
# 13         62834                      Assam
# 14          8845                    Tripura
# 15          4726          Arunachal Pradesh
# 16         49611                     Punjab
# 17         39653                  Jharkhand
# 18         10510                      Delhi
# 19          2044                 Chandigarh
# ...

# %%
Combined_bio['state'] = Combined_bio['state'].replace({
    'West  Bengal': 'West Bangal',
    'West bengal' : 'West Bangal'
      })

# %%
# Syntax: df['Column'].replace({ 'Old_Value_1': 'New_Value_1', 'Old_Value_2': 'New_Value_2' })

# Example: Standardizing Gender and State names
combined_demo['state'] = combined_demo['state'].replace({
   # 'Chhatisgarh': 'Chhattisgarh',
    #'Westbengal': 'West Bangal',
    'West bengal': 'West Bangal',
    #'west Bengal': 'West Bangal',
    'West  Bengal': 'West Bangal',
    #'Jaipur' : 'Rajasthan',
    #'Nagpur' : 'Maharastra',
    'Maharastra' : 'Maharashtra',
    #'Puttenahalli' : 'Karnataka',
    #'Darbhanga' : 'Bihar',
    #'Raja Annamalai Puram' : 'Tamil Nadu',
    #'Madanapalle' : 'Andhra Pradesh',
    #'Uttaranchal' : 'Uttarakhand',
    #'BALANAGAR' : 'Telangana'
     #'West Bengli': 'West Bangal'
   # 'Puducherry': 'Pondicherry',
    #'Jammu and Kashmir': 'Jammu & Kashmir',
    'ODISHA': 'Odisha',
    'odisha' : 'Odisha'
    
    #'Daman and Diu' : 'Daman & Diu',
    #'Dadra and Nagar Haveli' : 'Dadra & Nagar Haveli'
    #'Andaman and Nicobar Islands' : 'Andaman & Nicobar Islands'
})

# %%
print(combined_demo['state'].unique())
# Out:
# ['Uttar Pradesh' 'Andhra Pradesh' 'Gujarat' 'Rajasthan' 'Karnataka'
#  'West Bangal' 'Telangana' 'Odisha' 'Maharashtra' 'Kerala' 'Bihar'
#  'Tamil Nadu' 'Madhya Pradesh' 'Assam' 'Tripura' 'Arunachal Pradesh'
#  'Punjab' 'Jharkhand' 'Delhi' 'Chandigarh' 'Chhattisgarh'
#  'Jammu & Kashmir' 'Mizoram' 'Nagaland' 'Himachal Pradesh' 'Goa' 'Haryana'
#  'Meghalaya' 'Uttarakhand' 'Manipur' 'Daman & Diu' 'Pondicherry' 'Sikkim'
#  'Ladakh' 'Dadra & Nagar Haveli' 'Andaman & Nicobar Islands' 'Lakshadweep'
#  'andhra pradesh']

# %%
import pandas as pd

# 1. Identify the specific merged name
merged_name = "Dadra and Nagar Haveli and Daman and Diu"

# 2. Function to swap the string with a list of the two separate names
def split_ut(val):
    if val == merged_name:
        return ["Dadra and Nagar Haveli", "Daman and Diu"]
    return val

# 3. Apply the split and then explode
# This converts the string to a list ['Dadra...', 'Daman...']
combined_demo['state'] = combined_demo['state'].apply(split_ut)

# 4. Explode creates a new row for every item in the list
combined_demo = combined_demo.explode('state').reset_index(drop=True)

print(combined_demo)
# Out:
#                date           state        district  pincode  demo_age_5_17  \
# 0        01-03-2025   Uttar Pradesh       Gorakhpur   273213             49
# 1        01-03-2025  Andhra Pradesh        Chittoor   517132             22
# 2        01-03-2025         Gujarat          Rajkot   360006             65
# 3        01-03-2025  Andhra Pradesh      Srikakulam   532484             24
# 4        01-03-2025       Rajasthan         Udaipur   313801             45
# ...             ...             ...             ...      ...            ...
# 2072217  29-12-2025     West Bangal  West Midnapore   721212              0
# 2072218  29-12-2025     West Bangal  West Midnapore   721420              0
# 2072219  29-12-2025     West Bangal  West Midnapore   721424              0
# 2072220  29-12-2025     West Bangal  West Midnapore   721426              0
# 2072221  29-12-2025     West Bangal         hooghly   712701              0
#
#          demo_age_17_
# 0                 529
# ...

# %%
#state column has '100000' value which was irrelevant
indexes_to_drop = combined_enro[combined_enro['state'] == '100000'].index

# 2. Drop them
combined_enro.drop(indexes_to_drop, inplace=True)

# %%
pd.read_sql("select count(state) , state  from biometric group by state;", engine)
# Out:
#     count(state)                      state
# 0          26429                    Haryana
# 1          83398                      Bihar
# 2          19960            Jammu & Kashmir
# 3         184569                 Tamil Nadu
# 4         151104                Maharashtra
# 5          89531                    Gujarat
# 6          99674                     Odisha
# 7         130895                West Bangal
# 8          98511                     Kerala
# 9          79724                  Rajasthan
# 10         48108                     Punjab
# 11         30385           Himachal Pradesh
# 12        155242              Uttar Pradesh
# 13         47643                      Assam
# 14         22601                Uttarakhand
# 15         70080             Madhya Pradesh
# 16        141227                  Karnataka
# 17        172065             Andhra Pradesh
# 18         82579                  Telangana
# 19          5428                        Goa
# ...

# %%
#state column has '100000' value which was irrelevant
indexes_to_drop = Combined_bio[Combined_bio['state'] == '100000'].index

# 2. Drop them
Combined_bio.drop(indexes_to_drop, inplace=True)

# %%
Combined_bio['state'] = Combined_bio['state'].replace({
    'West  Bengal': 'West Bangal',
    'West bengal' : 'West Bangal'
      })

# %%
# Syntax: df['Column'].replace({ 'Old_Value_1': 'New_Value_1', 'Old_Value_2': 'New_Value_2' })

# Example: Standardizing Gender and State names
Combined_bio['state'] = Combined_bio['state'].replace({
   # 'Chhatisgarh': 'Chhattisgarh',
    #'Westbengal': 'West Bangal',
    'WEST BENGAL': 'West Bangal',
    'west Bengal': 'West Bangal',
    'West Bengal': 'West Bangal',
    'Jaipur' : 'Rajasthan',
    'Nagpur' : 'Maharastra',
    'Puttenahalli' : 'Karnataka',
    'Darbhanga' : 'Bihar',
    'Raja Annamalai Puram' : 'Tamil Nadu',
    'Madanapalle' : 'Andhra Pradesh',
    'Uttaranchal' : 'Uttarakhand',
    'BALANAGAR' : 'Telangana'
     #'West Bengli': 'West Bangal'
   # 'Puducherry': 'Pondicherry',
    #'Jammu and Kashmir': 'Jammu & Kashmir',
    #'Orissa': 'Odisha',
    #'Daman and Diu' : 'Daman & Diu',
    #'Dadra and Nagar Haveli' : 'Dadra & Nagar Haveli'
    #'Andaman and Nicobar Islands' : 'Andaman & Nicobar Islands'
})

# %%
import pandas as pd

# 1. Identify the specific merged name
merged_name = "Dadra and Nagar Haveli and Daman and Diu"

# 2. Function to swap the string with a list of the two separate names
def split_ut(val):
    if val == merged_name:
        return ["Dadra and Nagar Haveli", "Daman and Diu"]
    return val

# 3. Apply the split and then explode
# This converts the string to a list ['Dadra...', 'Daman...']
Combined_bio['state'] = Combined_bio['state'].apply(split_ut)

# 4. Explode creates a new row for every item in the list
Combined_bio = Combined_bio.explode('state').reset_index(drop=True)

print(Combined_bio)
# Out:
#                date            state        district  pincode  bio_age_5_17  \
# 0        01-03-2025          Haryana    Mahendragarh   123029           280
# 1        01-03-2025            Bihar       Madhepura   852121           144
# 2        01-03-2025  Jammu & Kashmir           Punch   185101           643
# 3        01-03-2025            Bihar         Bhojpur   802158           256
# 4        01-03-2025       Tamil Nadu         Madurai   625514           271
# ...             ...              ...             ...      ...           ...
# 1861327  29-12-2025      West Bengal  Uttar Dinajpur   733201             4
# 1861328  29-12-2025      West Bengal  Uttar Dinajpur   733213             0
# 1861329  29-12-2025      West Bengal  West Midnapore   721304             0
# 1861330  29-12-2025      West Bengal  West Midnapore   721451             2
# 1861331  29-12-2025      West Bengal  West Midnapore   721457             0
#
#          bio_age_17_
# 0                577
# ...

# %%
pd.read_sql("select count(state) , state  from enrollment group by state;", engine)
# Out:
#     count(state)                      state
# 0           3771                  Meghalaya
# 1          70198                  Karnataka
# 2         110369              Uttar Pradesh
# 3          60567                      Bihar
# 4          77191                Maharashtra
# 5          15997                    Haryana
# 6          56159                  Rajasthan
# 7          20439                     Punjab
# 8           6804                      Delhi
# 9          50225             Madhya Pradesh
# 10         76561                West Bangal
# 11         31827                      Assam
# 12         10007                Uttarakhand
# 13         46624                    Gujarat
# 14         65663             Andhra Pradesh
# 15         92552                 Tamil Nadu
# 16         18550               Chhattisgarh
# 17         23218                  Jharkhand
# 18          1999                   Nagaland
# 19          3218                    Manipur
# ...

# %%
# Syntax: df['Column'].replace({ 'Old_Value_1': 'New_Value_1', 'Old_Value_2': 'New_Value_2' })

# Example: Standardizing Gender and State names
combined_enro['state'] = combined_enro['state'].replace({
    #'Chhatisgarh': 'Chhattisgarh',
    #'WEST BENGAL': 'West Bangal',
    #'West Bengal': 'West Bangal',
    #'west Bengal': 'West Bangal',
    #'West  Bengal': 'West Bangal',
    #'Jaipur' : 'Rajasthan',
   # 'Nagpur' : 'Maharastra',
    #'Maharastra' : 'Maharashtra',
    #'Puttenahalli' : 'Karnataka',
    #'Darbhanga' : 'Bihar',
    #'Raja Annamalai Puram' : 'Tamil Nadu',
    #'Madanapalle' : 'Andhra Pradesh',
   # 'Uttaranchal' : 'Uttarakhand',
    #'BALANAGAR' : 'Telangana'
    #'West Bengli': 'West Bangal'
   # 'Puducherry': 'Pondicherry',
    'Jammu And Kashmir': 'Jammu & Kashmir',
    #'Orissa': 'Odisha',
    #'odisha' : 'Odisha'
    'Daman and Diu' : 'Daman & Diu',
    'Dadra and Nagar Haveli' : 'Dadra & Nagar Haveli'
   # 'Andaman and Nicobar Islands' : 'Andaman & Nicobar Islands'
})

# %%
import pandas as pd

# 1. Identify the specific merged name
merged_name1 = "The Dadra And Nagar Haveli And Daman And Diu"

# 2. Function to swap the string with a list of the two separate names
def split_ut(val):
    if val == merged_name1:
        return ["Dadra and Nagar Haveli", "Daman and Diu"]
    return val

# 3. Apply the split and then explode
# This converts the string to a list ['Dadra...', 'Daman...']
combined_enro['state'] = combined_enro['state'].apply(split_ut)

# 4. Explode creates a new row for every item in the list
combined_enro = combined_enro.explode('state').reset_index(drop=True)

print(combined_enro)
# Out:
#                date          state          district  pincode  age_0_5  \
# 0        02-03-2025      Meghalaya  East Khasi Hills   793121       11
# 1        09-03-2025      Karnataka   Bengaluru Urban   560043       14
# 2        09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29
# 3        09-03-2025  Uttar Pradesh           Aligarh   202133       62
# 4        09-03-2025      Karnataka   Bengaluru Urban   560016       14
# ...             ...            ...               ...      ...      ...
# 1006120  31-12-2025    West Bangal    West Midnapore   721149        2
# 1006121  31-12-2025    West Bangal    West Midnapore   721150        2
# 1006122  31-12-2025    West Bangal    West Midnapore   721305        0
# 1006123  31-12-2025    West Bangal    West Midnapore   721504        1
# 1006124  31-12-2025    West Bangal    West Midnapore   721517        2
#
#          age_5_17  age_18_greater
# 0              61              37
# 1              33              39
# ...

# %%
combined_enro.to_csv('New enrollment.csv', index= False)
combined_demo.to_csv('New demographic.csv', index= False)
Combined_bio.to_csv('New Biometric.csv ', index= False)
